# %%
import boto3
import json
from sql_metadata import Parser 
import re

# %%
s3 = boto3.client('s3',
                  endpoint_url='http://localhost:9000',
                  aws_access_key_id='minio',
                  aws_secret_access_key='minio123',
                  region_name='us-east-1')

# %%
r = s3.select_object_content(
    Bucket='d-dp-data-usage',
    Key='public/queries_history/date_2022_02_04/1643967955-0000000060_0.gz',
    ExpressionType='SQL',
    Expression="""
        select 
            s._1 as ctime,
            s._5 as user_name,
            s._6 as db,
            s._12 as rows_out,
            s._18 as query_text
        from s3object s
    """,
    InputSerialization={
        'CSV': {
        },
        'CompressionType': 'GZIP',
    },
    OutputSerialization={'JSON': {
        'RecordDelimiter': '\n'
    }},
)
# Out:
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:665, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664 # Make the request on the httplib connection object.
# --> 665 httplib_response = self._make_request(
#     666     conn,
#     667     method,
#     668     url,
#     669     timeout=timeout_obj,
#     670     body=body,
#     671     headers=headers,
#     672     chunked=chunked,
#     673 )
#     675 # If we're going to release the connection in ``finally:``, then
#     676 # the response doesn't need to know about the connection. Otherwise
#     677 # it will also try to release it and we'll have a double-release
#     678 # mess.
#
# ...

# %%
for event in r['Payload']:
    if 'Records' in event:
        records = event['Records']['Payload'].decode('utf-8')
        for item in records.split("\n"):
            sql = json.loads(item)['query_text']
            try:
                parser = Parser(sql)
                print(parser.tables)
            except ValueError:
                pass
# Out:
# Not supported query type: set search_path to tpnet_tpnsql00088_tpcentraldb_ods; select hi42_marts.fn_load_ticcai_lines_ticket_date('88'\
# Not supported query type: set search_path to tpnet_tpnsql00088_tpcentraldb_ods; select hi42_marts.fn_load_ticcai_lines_ticket_date('88'\
# Not supported query type: set search_path to tpnet_tpnsql00016_tpcentraldb_ods; select hi42_marts.fn_load_ticcai_lines_ticket_date('16'\
# Not supported query type: set search_path to tpnet_tpnsql00088_tpcentraldb_ods; select hi42_marts.fn_load_ticcai_lines_ticket_date('88'\
# Not supported query type: set search_path to tpnet_tpnsql00088_tpcentraldb_ods; select hi42_marts.fn_load_ticcai_lines_ticket_date('88'\
# Not supported query type: set optimizer = off; select hi42_marts.fn_load_hi42_union('2020-09-28'::date);
# Not supported query type: set search_path to tpnet_tpnsql00088_tpcentraldb_ods; select hi42_marts.fn_load_ticcai_lines_ticket_date('88'\
# ...

# %%
r = s3.select_object_content(
    Bucket='d-dp-data-usage',
    Key='/public/queries_history/date_2022_02_03/1643876009-0000000022_0.parquet',
    ExpressionType='SQL',
    Expression="""
        select 
           *
        from s3object s
    """,
    InputSerialization={
        'Parquet': {}
    },
    OutputSerialization={'JSON': {
        'RecordDelimiter': '\n'
    }},
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Input In [133], in <module>
# ----> 1 r = s3.select_object_content(
#       2     Bucket='d-dp-data-usage',
#       3     Key='/public/queries_history/date_2022_02_03/1643876009-0000000022_0.parquet',
#       4     ExpressionType='SQL',
#       5     Expression="""
#       6         select
#       7            *
#       8         from s3object s
#       9     """,
#      10     InputSerialization={
#      11         'Parquet': {}
#      12     },
#      13     OutputSerialization={'JSON': {
#      14         'RecordDelimiter': '\n'
#      15     }},
#      16 )
#
# File ~/.local/lib/python3.8/site-packages/botocore/client.py:276, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     273     raise TypeError(
#     274         "%s() only accepts keyword arguments." % py_operation_name)
# ...

# %%
# for key in s3.list_objects(Bucket='bucket_name'):
#     print(key)
print(dir(s3))
# Out:
# ['_PY_TO_OP_NAME', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_cache', '_client_config', '_convert_to_request_dict', '_emit_api_params', '_endpoint', '_exceptions', '_exceptions_factory', '_get_waiter_config', '_load_exceptions', '_loader', '_make_api_call', '_make_request', '_register_handlers', '_request_signer', '_response_parser', '_serializer', '_service_model', 'abort_multipart_upload', 'can_paginate', 'complete_multipart_upload', 'copy', 'copy_object', 'create_bucket', 'create_multipart_upload', 'delete_bucket', 'delete_bucket_analytics_configuration', 'delete_bucket_cors', 'delete_bucket_encryption', 'delete_bucket_inventory_configuration', 'delete_bucket_lifecycle
# ...

# %%
for key in s3.list_objects(Bucket='d-dp-data-usage', Prefix='public/queries_history')['Contents']:
    print(key['Key'])
# Out:
# public/queries_history/date_2022_02_03/1643876009-0000000015_0.snappy.parquet
# public/queries_history/date_2022_02_03/1643876009-0000000015_1.snappy.parquet
# public/queries_history/date_2022_02_03/1643876009-0000000017_0.gz
# public/queries_history/date_2022_02_03/1643876009-0000000017_1.gz
# public/queries_history/date_2022_02_03/1643876009-0000000020_0.snappy.parquet
# public/queries_history/date_2022_02_03/1643876009-0000000020_1.snappy.parquet
# public/queries_history/date_2022_02_03/1643876009-0000000022_0.parquet
# public/queries_history/date_2022_02_03/1643876009-0000000022_1.parquet

# %%
s3.list_buckets()
# Out:
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:665, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664 # Make the request on the httplib connection object.
# --> 665 httplib_response = self._make_request(
#     666     conn,
#     667     method,
#     668     url,
#     669     timeout=timeout_obj,
#     670     body=body,
#     671     headers=headers,
#     672     chunked=chunked,
#     673 )
#     675 # If we're going to release the connection in ``finally:``, then
#     676 # the response doesn't need to know about the connection. Otherwise
#     677 # it will also try to release it and we'll have a double-release
#     678 # mess.
#
# ...
